# %%
# First let's import the packages we will use in this project
# You can do this all now or as you need them
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None


# Now we need to read in the data
df = pd.read_csv(r'C:\Users\nature\Desktop\data_analyst_project\movies.csv')

# %%
# Now let's take a look at the data

# to look at all the rows in the dataset ---> pd.set_option('display.max_rows', None)

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# We need to see if we have any missing data
# Let's loop through the data and see if there is anything missing

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0.0%
# rating - 1.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 28.0%
# gross - 2.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Checking how many missing values are present in each column

missing_values_col = df.isnull().sum()
print('Missing values in each column:\n\n', missing_values_col)

print('\n\n')

# checking total number of missing values in the entire dataframe

missing_values_df = df.isnull().sum().sum()
print('Missing values in the entire dataframe:', missing_values_df)
# Out:
# Missing values in each column:
#
#  name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64
#
#
#
# Missing values in the entire dataframe: 2473

# %%
# Drop all rows containing missing values

df.dropna(axis=0, how='any', inplace=True)

# %%
# Checking again for missing values in each column, if present

df.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
# Data Types for our columns

print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# change data type of columns

# df['budget'] = df['budget'].astype('int64') ---> this one is for data type conversion for a single column

df = df.astype({'budget': 'int64', 'gross': 'int64', 'runtime': 'int64'}) # converts data type enclosing multiple columns

# %%
# Create correct year column

def get_date(date):
    if '(' in date:
        date = date[:date.index('(')]
    return date[:-1].strip()

df['yearcorrect'] = df['released'].apply(lambda date: get_date(str(date))).str[-4:]

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Drop the released column

df.drop(columns=["released"], inplace=True)

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#    score      votes         director                   writer            star  \
# 0    8.4   927000.0  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2    8.7  1200000.0   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3    7.7   221000.0     Jim Abrahams             Jim Abrahams     Robert Hays
# 4    7.3   108000.0     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
# ...

# %%
# Are there any Outliers?

df.boxplot(column=['gross'])

# %%
# Drop any duplicates

df.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# 5                                    Friday the 13th          R     Horror
# 6                                 The Blues Brothers          R     Action
# 7                                        Raging Bull          R  Biography
# 8                                        Superman II         PG     Action
# 9                                    The Long Riders          R  Biography
# 10                             Any Which Way You Can         PG     Action
# ...

# %%
# Order our Data a little bit to see

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                                name     rating      genre  \
# 5445                                         Avatar      PG-13     Action
# 7445                              Avengers: Endgame      PG-13     Action
# 3045                                        Titanic      PG-13      Drama
# 6663     Star Wars: Episode VII - The Force Awakens      PG-13     Action
# 7244                         Avengers: Infinity War      PG-13     Action
# 7480                                  The Lion King         PG  Animation
# 6653                                 Jurassic World      PG-13     Action
# 6043                                   The Avengers      PG-13     Action
# 6646                                      Furious 7      PG-13     Action
# 7494                                      Frozen II         PG  Animation
# 6644                        Avengers: Age of Ultron      PG-13     Action
# 7247                                  Black Panther      PG-13     Action
# ...

# %%
sns.regplot(x="gross", y="budget", data=df, scatter_kws={'color': 'red'}, line_kws={'color': 'blue'})

# %%
sns.regplot(x="score", y="gross", data=df, scatter_kws={'color': 'red'}, line_kws={'color': 'blue'})

# %%
# Correlation Matrix between all numeric columns

df.corr(method ='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
df.corr(method ='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.039389  0.296512  0.220833  0.239539  0.064824
# score    0.039389  1.000000  0.350185 -0.006406  0.124943  0.292254
# votes    0.296512  0.350185  1.000000  0.346274  0.553625  0.205344
# budget   0.220833 -0.006406  0.346274  1.000000  0.512057  0.231278
# gross    0.239539  0.124943  0.553625  0.512057  1.000000  0.176979
# runtime  0.064824  0.292254  0.205344  0.231278  0.176979  1.000000

# %%
df.corr(method ='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.057741  0.427623  0.312886  0.351045  0.095444
# score    0.057741  1.000000  0.495409 -0.009971  0.183192  0.412155
# votes    0.427623  0.495409  1.000000  0.493461  0.745793  0.300621
# budget   0.312886 -0.009971  0.493461  1.000000  0.692958  0.330794
# gross    0.351045  0.183192  0.745793  0.692958  1.000000  0.257400
# runtime  0.095444  0.412155  0.300621  0.330794  0.257400  1.000000

# %%
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
# Using factorize - this assigns a random numeric value for each unique categorical value

df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#                  name    rating     genre      year     score     votes  \
# name         1.000000  0.169808  0.028413  0.965461 -0.020083  0.297305
# rating       0.169808  1.000000 -0.116507  0.179456  0.036114  0.097619
# genre        0.028413 -0.116507  1.000000  0.031765 -0.027402 -0.009983
# year         0.965461  0.179456  0.031765  1.000000 -0.014594  0.323916
# score       -0.020083  0.036114 -0.027402 -0.014594  1.000000 -0.041981
# votes        0.297305  0.097619 -0.009983  0.323916 -0.041981  1.000000
# director     0.725411  0.096014  0.036671  0.747785 -0.006583  0.187909
# writer       0.791872  0.128909  0.033975  0.812386 -0.021538  0.225105
# star         0.695124  0.115694  0.045497  0.719373  0.015108  0.182043
# country      0.098110 -0.004547 -0.003314  0.095073  0.016567 -0.021562
# budget       0.288955  0.203698  0.020893  0.319135 -0.005493  0.359065
# gross        0.967925  0.172703  0.032033  0.996371 -0.015744  0.307248
# ...

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name         name           1.000000
#              rating         0.169808
#              genre          0.028413
#              year           0.965461
#              score         -0.020083
#              votes          0.297305
#              director       0.725411
#              writer         0.791872
#              star           0.695124
#              country        0.098110
#              budget         0.288955
#              gross          0.967925
#              company        0.535369
#              runtime        0.048980
#              yearcorrect    0.921688
# rating       name           0.169808
#              rating         1.000000
#              genre         -0.116507
#              year           0.179456
#              score          0.036114
#              votes          0.097619
#              director       0.096014
#              writer         0.128909
#              star           0.115694
#              country       -0.004547
# ...

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# genre        rating        -0.116507
# rating       genre         -0.116507
# budget       company       -0.053573
# company      budget        -0.053573
# votes        score         -0.041981
# score        votes         -0.041981
# genre        score         -0.027402
# score        genre         -0.027402
# runtime      director      -0.026918
# director     runtime       -0.026918
# rating       company       -0.026286
# company      rating        -0.026286
# votes        country       -0.021562
# country      votes         -0.021562
# writer       score         -0.021538
# score        writer        -0.021538
#              name          -0.020083
# name         score         -0.020083
# score        gross         -0.015744
# gross        score         -0.015744
# year         score         -0.014594
# score        year          -0.014594
#              yearcorrect   -0.012946
# yearcorrect  score         -0.012946
# runtime      company       -0.010695
# ...

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# company      yearcorrect    0.506753
# yearcorrect  company        0.506753
# company      name           0.535369
# name         company        0.535369
# year         company        0.537731
# company      year           0.537731
# gross        company        0.545924
# company      gross          0.545924
# writer       star           0.626647
# star         writer         0.626647
# director     star           0.636705
# star         director       0.636705
# yearcorrect  star           0.684736
# star         yearcorrect    0.684736
# name         star           0.695124
# star         name           0.695124
# yearcorrect  director       0.708189
# director     yearcorrect    0.708189
#              writer         0.717990
# writer       director       0.717990
# star         year           0.719373
# year         star           0.719373
# gross        star           0.720811
# star         gross          0.720811
# director     name           0.725411
# ...

# %%
# Looking at the top 15 compaies by gross revenue

CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross']

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 54610959970
# Universal Pictures           51241105418
# Columbia Pictures            42356430218
# Paramount Pictures           40021704691
# Twentieth Century Fox        39542573303
# Walt Disney Pictures         35833650748
# New Line Cinema              19612851164
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Dreamworks Pictures          11593807697
# Touchstone Pictures          10664679494
# Metro-Goldwyn-Mayer (MGM)     8937010092
# Summit Entertainment          8318570396
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7243673721
# Name: gross, dtype: int64

# %%
df.groupby(['company', 'year'])[["gross"]].sum()
# Out:
#                                               gross
# company                             year
# "DIA" Productions GmbH & Co. KG     2003   44350926
# "Weathering With You" Film Partners 2019  193457467
# .406 Production                     1996      10580
# 1492 Pictures                       1996  129832389
#                                     1999   87423861
# 1818 Productions                    1983   12232628
# 19 Entertainment                    2003    4928883
# 1978 Films                          2017   40656399
# 1984 Private Defense Contractors    2014   58834384
# 2 Loop Films                        2002     264349
# 2.0 Entertainment                   2019  122810399
# 2.4.7. Films                        2007   22783978
# 2003 Productions                    2004   69424389
# 20th Century Studios                2020  111105497
# 21 Laps Entertainment               2014   41296320
#                                     2018   41142379
# ...

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company                year
# Walt Disney Pictures   2019    5773131804
# Marvel Studios         2018    4018631866
# Universal Pictures     2015    3834354888
# Twentieth Century Fox  2009    3793491246
# Walt Disney Pictures   2017    3789382071
# Paramount Pictures     2011    3565705182
# Warner Bros.           2011    3223799224
# Walt Disney Pictures   2010    3104474158
# Paramount Pictures     2014    3071298586
# Columbia Pictures      2006    2934631933
#                        2019    2932757449
# Marvel Studios         2019    2797501328
# Warner Bros.           2018    2774168962
# Columbia Pictures      2011    2738363306
# Warner Bros.           2005    2688767210
# Name: gross, dtype: int64

# %%
plt.scatter(x=df['budget'], y=df['gross'], alpha=0.5)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()
